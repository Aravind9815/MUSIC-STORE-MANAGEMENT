# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\sql project inno\sql project data\employee.csv")
df
# Out:
#    employee_id last_name first_name                   title  reports_to  \
# 0            1     Adams     Andrew         General Manager         9.0
# 1            2   Edwards      Nancy           Sales Manager         1.0
# 2            3   Peacock       Jane     Sales Support Agent         2.0
# 3            4      Park   Margaret     Sales Support Agent         2.0
# 4            5   Johnson      Steve     Sales Support Agent         2.0
# 5            6  Mitchell    Michael              IT Manager         1.0
# 6            7      King     Robert                IT Staff         6.0
# 7            8  Callahan      Laura                IT Staff         6.0
# 8            9     Madan      Mohan  Senior General Manager         NaN
#
#   levels   birthdate   hire_date                      address        city  \
# 0     L6  02/18/1962  08/14/2016          11120 Jasper Ave NW    Edmonton
# 1     L4  12/08/1958  05/01/2016                 825 8 Ave SW     Calgary
# ...

# %%
df["reports_to"].fillna(0,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_8128\535883063.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["reports_to"].fillna(0,inplace=True)

# %%
df
# Out:
#    employee_id last_name first_name                   title  reports_to  \
# 0            1     Adams     Andrew         General Manager         9.0
# 1            2   Edwards      Nancy           Sales Manager         1.0
# 2            3   Peacock       Jane     Sales Support Agent         2.0
# 3            4      Park   Margaret     Sales Support Agent         2.0
# 4            5   Johnson      Steve     Sales Support Agent         2.0
# 5            6  Mitchell    Michael              IT Manager         1.0
# 6            7      King     Robert                IT Staff         6.0
# 7            8  Callahan      Laura                IT Staff         6.0
# 8            9     Madan      Mohan  Senior General Manager         0.0
#
#   levels   birthdate   hire_date                      address        city  \
# 0     L6  02/18/1962  08/14/2016          11120 Jasper Ave NW    Edmonton
# 1     L4  12/08/1958  05/01/2016                 825 8 Ave SW     Calgary
# ...

# %%
# converted mm/dd/yyyy to yyyy/mm/dd .because it accepts only yyyy/mm/dd datae format

# %%
df["birthdate"] = ["1962/02/18" , "1958/12/08"
,"1973/08/29"
,   "1947/09/19"
,    "1965/03/03"
,   "1973/07/01"
,   "1970/05/29"
,   "1968/01/09"
,    "1961/01/26"]

# %%
df["hire_date"]= ['2016/08/14',
 '2016/05/01',
 '2017/04/01',
 '2017/05/03',
 '2017/10/17',
 '2016/10/17',
 '2017/01/02',
 '2017/03/04',
 '2016/01/14']

# %%
df
# Out:
#    employee_id last_name first_name                   title  reports_to  \
# 0            1     Adams     Andrew         General Manager         9.0
# 1            2   Edwards      Nancy           Sales Manager         1.0
# 2            3   Peacock       Jane     Sales Support Agent         2.0
# 3            4      Park   Margaret     Sales Support Agent         2.0
# 4            5   Johnson      Steve     Sales Support Agent         2.0
# 5            6  Mitchell    Michael              IT Manager         1.0
# 6            7      King     Robert                IT Staff         6.0
# 7            8  Callahan      Laura                IT Staff         6.0
# 8            9     Madan      Mohan  Senior General Manager         0.0
#
#   levels   birthdate   hire_date                      address        city  \
# 0     L6  1962/02/18  2016/08/14          11120 Jasper Ave NW    Edmonton
# 1     L4  1958/12/08  2016/05/01                 825 8 Ave SW     Calgary
# ...

# %%
df.to_csv("D:\sql project inno\sql project data\employee(updated).csv",index=False)

# %%
df = pd.read_csv(r"D:\sql project inno\sql project data\track.csv")

# %%
df.isnull().sum()
# Out:
# track_id           0
# name               0
# album_id           0
# media_type_id      0
# genre_id           0
# composer         978
# milliseconds       0
# bytes              0
# unit_price         0
# dtype: int64

# %%
# in sql if you mention varchar then it should not contains the null values .if contains it remove entire row while importing the data(csv files)

# %%
df["composer"].fillna("blank_space",inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_8128\4114469308.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["composer"].fillna("blank_space",inplace=True)

# %%
df.isnull().sum()
# Out:
# track_id         0
# name             0
# album_id         0
# media_type_id    0
# genre_id         0
# composer         0
# milliseconds     0
# bytes            0
# unit_price       0
# dtype: int64

# %%
df.to_csv(r"D:\sql project inno\sql project data\track(updated).csv",index=False)
